# %% [markdown]
# # Laboratoire SIG – SQL et statistiques
#
# ## Objectif
# Explorer un jeu de données de production primaire, effectuer des requêtes SQL, puis analyser les données dans une région d’intérêt.

# %% [markdown]
# ## 1. Chargement des données
#
# **Consignes :**
# - Charger le fichier CSV situé dans le dossier `data/`
# - Vérifier les colonnes présentes
# - Afficher les premières lignes

# %%
# À compléter

# %% [markdown]
# ## 2. Exploration du jeu de données
#
# **Questions :**
# 1. Combien de lignes contient le jeu de données ?
# 2. Quelles sont les variables disponibles ?

# %%
# À compléter

# %% [markdown]
# ## 3. Création d'une base de données SQLite
#
# **Consignes :**
# - Créer une base de données
# - Importer le CSV dans une table nommée `pp_data`

# %%
# À compléter

# %% [markdown]
# ## 4. Requêtes SQL
#
# **Questions :**
# 1. Combien de pixels contient la base de données ?
# 2. Quelle est la valeur minimale et maximale de `pp_open` ?
# 3. Quelle est la moyenne de `pp_open` ?
# 4. Combien de pixels ont une valeur supérieure à 1000 ?

# %%
# Écrire vos requêtes SQL ici

# %% [markdown]
# ## 5. Conversion en données spatiales
#
# **Consignes :**
# - Convertir le tableau en GeoDataFrame
# - Utiliser les colonnes `lat` et `lon`

# %%
# À compléter

# %% [markdown]
# ## 6. Chargement du shapefile
#
# **Consignes :**
# - Charger le shapefile de la région
# - Vérifier le système de coordonnées

# %%
# À compléter

# %% [markdown]
# ## 7. Sélection spatiale
#
# **Consignes :**
# - Extraire les points situés dans la région
# - Compter le nombre de points

# %%
# À compléter

# %% [markdown]
# ## 8. Statistiques descriptives
#
# **Questions :**
# 1. Quelle est la moyenne de `pp_open` dans la région ?
# 2. Quel est l’écart-type ?
# 3. Quelle est la valeur minimale et maximale ?

# %%
# À compléter

# %% [markdown]
# ## 9. Interprétation
#
# **Questions :**
# - Comment se compare la moyenne régionale à la moyenne globale ?
# - Les valeurs sont-elles homogènes ou variables ?
# - Quelles limites peut-on identifier dans cette analyse ?
