# %% [markdown]
# # Laboratoire SIG - SQL et programmation Python
#
# ## 1. Introduction et objectifs
#
# Dans ce laboratoire, vous allez explorer un jeu de données de production primaire avec SQL, puis sélectionner les points situés dans une région d’intérêt à l’aide d’un shapefile.
#
# **Variables du CSV :**
# - `latitude`
# - `longitude`
# - `pp_open`
#
# **Objectifs :**
# - charger un fichier CSV ;
# - créer une base SQLite ;
# - écrire des requêtes SQL simples ;
# - convertir les données en objets spatiaux ;
# - sélectionner les points dans une région ;
# - calculer des statistiques descriptives.

# %% [markdown]
# ## 2. Importer les bibliothèques
#
# **Consigne :** importer les bibliothèques nécessaires au laboratoire.
#
# **Indice :** vous aurez besoin de `pandas`, `sqlite3`, `geopandas`, `Point` depuis `shapely.geometry` et `statistics`.

# %%
# À compléter

# %% [markdown]
# ## 3. Charger le fichier CSV
#
# **Consigne :** lire le fichier `data/cci_v6_2003226_ppz_takuvik_above_45n_v2.csv` dans un DataFrame.
#
# **Indice :** utilisez une fonction de `pandas` pour lire un CSV.

# %%
# À compléter

# %% [markdown]
# ## 4. Explorer les colonnes et le contenu
#
# **Questions :**
# 1. Quels sont les noms des colonnes ?
# 2. Combien de lignes contient le fichier ?
# 3. Quel est le type des variables ?
#
# **Indice :** utilisez `columns`, `len()` et `dtypes`.

# %%
# À compléter

# %% [markdown]
# ## 5. Créer la base SQLite
#
# **Consignes :**
# - créer une connexion à une base nommée `pp_database.sqlite` ;
# - enregistrer le DataFrame dans une table appelée `pp_data`.
#
# **Indice :** utilisez `sqlite3.connect()` puis une méthode de `pandas` pour écrire dans SQL.

# %%
# À compléter

# %% [markdown]
# ## 6. Requête SQL 1 : nombre de pixels
#
# Écrire une requête SQL qui compte le nombre total de pixels dans `pp_data`.
#
# **Indice :** utilisez `COUNT(*)`.

# %%
# À compléter

# %% [markdown]
# ## 7. Requête SQL 2 : minimum et maximum
#
# Trouver les valeurs minimale et maximale de `pp_open`.
#
# **Indice :** utilisez `MIN()` et `MAX()`.

# %%
# À compléter

# %% [markdown]
# ## 8. Requête SQL 3 : moyenne globale
#
# Calculer la moyenne globale de `pp_open`.
#
# **Indice :** utilisez `AVG()`.

# %%
# À compléter

# %% [markdown]
# ## 9. Requête SQL 4 : pixels au-dessus d’un seuil
#
# Compter combien de pixels ont une valeur de `pp_open` supérieure à 1000.
#
# **Indice :** combinez `COUNT(*)` avec `WHERE`.

# %%
# À compléter

# %% [markdown]
# ## 10. Requête SQL 5 : filtre par latitude
#
# Extraire les observations dont la `latitude` est supérieure à 75.
#
# **Indice :** utilisez `WHERE latitude > 75`.

# %%
# À compléter

# %% [markdown]
# ## 11. Convertir le tableau en GeoDataFrame
#
# **Consignes :**
# - créer une géométrie à partir de `longitude` et `latitude` ;
# - convertir le DataFrame en `GeoDataFrame` avec le système `EPSG:4326`.
#
# **Indice :** utilisez `Point()` puis `gpd.GeoDataFrame()`.

# %%
# À compléter

# %% [markdown]
# ## 12. Charger le shapefile
#
# **Consigne :** lire le shapefile `data/WDPA_WDOECM_Feb2025_Public_555637925_shp-polygons.shp`.
#
# **Indice :** utilisez `geopandas.read_file()`.

# %%
# À compléter

# %% [markdown]
# ## 13. Vérifier / harmoniser le système de coordonnées
#
# **Consignes :**
# - vérifier le système de coordonnées du shapefile ;
# - harmoniser le shapefile avec le même SCR que les points.
#
# **Indice :** utilisez `.crs` et `to_crs()`.

# %%
# À compléter

# %% [markdown]
# ## 14. Faire la sélection spatiale
#
# **Consigne :** extraire les points situés à l’intérieur de la région.
#
# **Indice :** utilisez `gpd.sjoin()` avec `predicate='within'`.

# %%
# À compléter

# %% [markdown]
# ## 15. Compter les points dans la région
#
# **Question :** combien de pixels se trouvent dans la région sélectionnée ?
#
# **Indice :** utilisez `len()`.

# %%
# À compléter

# %% [markdown]
# ## 16. Calculer les statistiques descriptives
#
# **Consignes :** calculer, pour `pp_open` dans la région :
# - la moyenne ;
# - l’écart-type ;
# - le minimum ;
# - le maximum.
#
# **Indice :** commencez par extraire la colonne `pp_open`, retirer les valeurs manquantes, puis utilisez `statistics.mean()` et `statistics.stdev()`.

# %%
# À compléter

# %% [markdown]
# ## 17. Interpréter les résultats
#
# **Questions d’interprétation :**
# 1. La moyenne dans la région est-elle plus forte ou plus faible que la moyenne globale ?
# 2. L’écart-type suggère-t-il une faible ou une forte variabilité ?
# 3. Que révèlent les valeurs minimale et maximale sur la dispersion des données ?
# 4. Quelles sont les limites de cette approche ?

# %%
# Répondre aux questions ici sous-forme de commentaires

# %% [markdown]
# ## 18. Fermer la connexion
#
# **Consigne :** fermer proprement la connexion à la base de données.
#
# **Indice :** utilisez la méthode `.close()` de la connexion.

# %%
# À compléter
