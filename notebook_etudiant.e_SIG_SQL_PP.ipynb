# %% [markdown]
# # Laboratoire SIG – SQL et statistiques (version guidée)
#
# ## Objectif
# Explorer un jeu de données de production primaire, effectuer des requêtes SQL, puis analyser les données dans une région d’intérêt.
#
# 💡 Ce notebook contient des **indices** pour vous aider. Essayez d'abord par vous-même avant de lire les indices.

# %% [markdown]
# ## Fichiers utilisés
#
# - CSV : `data/cci_v6_2003226_ppz_takuvik_above_45n_v2.csv`
# - shapefile : `data/WDPA_WDOECM_Feb2025_Public_555637925_shp-polygons.shp`
#
# ## Variables importantes du CSV
#
# - `latitudeitude` : latitudeitude
# - `longitudegitude` : longitudegitude
# - `pp_open` : valeur de production primaire

# %% [markdown]
# Premièrement, il faut installer nos libraries pour réaliser notre laboratoire, nous aurons besoin des suivantes :

# %% [markdown]
# - `pandas` : lire le CSV et manipuler des tableaux de données ;
# - `sqlite3` : créer une petite base de données SQLite pour les requêtes SQL ;
# - `geopandas` : manipuler des données spatiales ;
# - `Point` : créer une géométrie de point à partir des coordonnées ;
# - `statistics` : calculer moyenne et écart-type.

# %%
# À compléter

# %% [markdown]
# ## 1. Charger le fichier CSV
#
# **Consignes :**
# - Charger le fichier CSV dans un DataFrame
# - Vérifier les colonnes
# - Afficher les premières lignes
#
# 💡 *Indice : utilisez une fonction de pandas pour lire un fichier CSV*

# %%
# À compléter

# %% [markdown]
# ## 2. Explorer les données
#
# **Questions :**
# 1. Combien de lignes contient le dataset ?
# 2. Quels sont les noms des colonnes ?
#
# 💡 *Indice : utilisez `len()` et une fonction pour afficher les colonnes*

# %%
# À compléter

# %% [markdown]
# ## 3. Créer une base SQLite
#
# **Consignes :**
# - Créer une connexion à une base SQLite
# - Sauvegarder le DataFrame dans une table appelée `pp_data`
#
# 💡 *Indice : utilisez `sqlite3.connect()` et une méthode de pandas*

# %%
# À compléter

# %% [markdown]
# ## 4. Requêtes SQL
#
# **Questions :**
# 1. Combien de pixels ?
# 2. Minimum et maximum de `pp_open`
# 3. Moyenne de `pp_open`
# 4. Nombre de pixels > 1000
#
# 💡 *Indice : utilisez COUNT, MIN, MAX, AVG et WHERE*

# %%
# Écrire vos requêtes SQL ici

# %% [markdown]
# ## 5. Convertir en données spatiales
#
# **Consignes :**
# - Créer une géométrie à partir de `longitudegitude` et `latitudeitude`
# - Convertir en GeoDataFrame
#
# 💡 *Indice : utilisez Point(longitude, latitude) et geopandas*

# %%
# À compléter

# %% [markdown]
# ## 6. Charger le shapefile
#
# **Consignes :**
# - Lire le shapefile
# - Vérifier ou adapter le système de coordonnées
#
# 💡 *Indice : utilisez geopandas.read_file() et to_crs()*

# %%
# À compléter

# %% [markdown]
# ## 7. Sélection spatiale
#
# **Consignes :**
# - Extraire les points dans la région
# - Compter les points
#
# 💡 *Indice : utilisez une jointure spatiale avec `sjoin()`*

# %%
# À compléter

# %% [markdown]
# ## 8. Statistiques descriptives
#
# **Questions :**
# - Moyenne
# - Écart-type
# - Min et max
#
# 💡 *Indice : utilisez le module `statistics` ou des fonctions de base Python*

# %%
# À compléter

# %% [markdown]
# ## 9. Interprétation
#
# **Questions :**
# 1. La région présente-t-elle une production primaire plus élevée ou plus faible que l'ensemble des données ?
# 2. L'écart-type est-il élevé ? Cela suggère-t-il une forte variabilité spatiale ?
# 3. Le minimum et le maximum montrent-ils une dispersion importante ?
# 4. Le résultat dépend-il du choix de la région et du fait que le shapefile contienne une ou plusieurs zones ?

# %%
# Vos réponses aux questions ici
